# %% [markdown]
# # ¡Hola Daniel!
#
# Mi nombre es Ezequiel Ferrario, soy code reviewer en Tripleten y tengo el agrado de revisar el proyecto que entregaste.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Encontrarás mis comentarios más abajo - **por favor, no los muevas, no los modifiques ni los borres**.
#
# ¿Cómo lo voy a hacer? Voy a leer detenidamente cada una de las implementaciones que has llevado a cabo para cumplir con lo solicitado. Verás los comentarios de esta forma:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si todo está perfecto.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta. Se aceptan uno o dos comentarios de este tipo en el borrador, pero si hay más, deberá hacer las correcciones. Es como una tarea de prueba al solicitar un trabajo: muchos pequeños errores pueden hacer que un candidato sea rechazado.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Hola, muchas gracias por tus comentarios y la revisión.
# </div>
#
# ¡Empecemos!

# %% [markdown]
# ----
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario general #1</b> <a class="tocSkip"></a>
#
# Daniel, hiciste un gran trabajo aqui.
#
# Completaste todos los puntos, y te manejaste perfecto en cada uno de ellos.
#
# Tanto la exploracion incial como la limpieza de los datasets fue muy buena, donde encontraste patrones y entendiste cada punto.
#
# A su vez, todos los graficos estan bien planteados y  lograste excelentes extraccion.
#
# Destaco todos tus comentarios ya que fueron minuciosos y claros.
#
# Asi, restan minimos detalles por corregir referente a las librerias y carga de dataset.
#
# Quedo atento a tu correccion, saludos.
#
#
# </div>
#
#
# ----
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario general #2</b> <a class="tocSkip"></a>
#
# Daniel, abarcaste las correcciones a la perfeccion.
#
# Entendiste como realizar cada grafico y extraccion, donde dejaste buenas conclusiones.
#
# Es asi que este proyecto llega a su fin y pasa a estar **aprobado**.
#
# Exitos en lo que viene, saludos.
#
# </div>
#
# ---

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# En este caso podes hacer una tabla de contenidos que este  linkeada a las secciones (al clickear debe llevarnos a esa seccion) de esta menera es mas facil desplazarse.
#
# Como consejo, si realizas bien todas las secciones (con su respectivo #) podes generarlo automáticamente desde jupyter lab. Para hacerlo, en la pestaña de herramientas de jupyter lab clickeas en el **botón de los puntos y barras**  (Table of contents) te generara automáticamente una tabla de contenidos linkeable y estética. A la **derecha** del seleccionador del tipo de celda (code/markdown)
# </div>

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
# importar librerías
import pandas as pd
from matplotlib import pyplot as plt

# %%
# leer conjuntos de datos en los DataFrames
instacart = pd.read_csv('/datasets/instacart_orders.csv', sep = ';')
products = pd.read_csv('/datasets/products.csv', sep = ';')
orders = pd.read_csv('/datasets/order_products.csv', sep = ';')
aisles = pd.read_csv('/datasets/aisles.csv', sep = ';')
departments = pd.read_csv('/datasets/departments.csv', sep = ';')

# %%
# mostrar información del DataFrame
instacart.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# mostrar información del DataFrame
products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
# mostrar información del DataFrame
orders.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
# mostrar información del DataFrame
aisles.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
# mostrar información del DataFrame
departments.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# - Los dataframes no están separados por comas, por lo tanto, se agrega 'sep' para incorporar el separador correcto ';'.
# - En el Dataframe Instacart, 5 de las 6 variables  son enteros, y 1 variable es flotante. Esta última variable tiene datos nulos.
# - En el Dataframe Products, la variable 'product_name' es de tipo 'object', esto indica que puede coontener enteros, flotantes, strings. Tiene datos nulos.
# - En el Dataframe Orders, tiene datos nulos.
# - Los últimos dos Dataframes, no tienen datos nulos.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente exploracion inicial.
#
#
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
# - Al ejecutar el método info() revisamos que todos los ID sean enteros.
# - Procederemos a identificar que DataFrames tienen valores NaN y duplicados, con el método duplicated().

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
print(instacart.duplicated().sum())
print(instacart['order_id'].nunique())
instacart.shape
# Out:
# 15
# 478952
# (478967, 6)

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.


#print(instacart.query("order_dow == 3 & order_hour_of_day == 2").duplicated().sum() )
#print(instacart[instacart.duplicated(keep=False)])
duplicated_data = instacart[instacart.duplicated(keep=False)].reset_index(drop=True)
print(duplicated_data)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    1918001   188546            14          3                  2
# 1     794638    50898            24          3                  2
# 2     408114    68324             4          3                  2
# 3    2845099    31189            11          3                  2
# 4     794638    50898            24          3                  2
# 5    1112182   202304            84          3                  2
# 6    1782114   106752             1          3                  2
# 7    2125197    14050            48          3                  2
# 8    2160484   107525            16          3                  2
# 9    2160484   107525            16          3                  2
# 10   1918001   188546            14          3                  2
# 11   1021560    53767             3          3                  2
# 12    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Qué sugiere este resultado?
# - Que todos los pedidos realizados el día Miércoles a las 2 am están duplicados y deben eliminarse los duplicados.

# %%
# Elimina los pedidos duplicados
instacart = instacart.drop_duplicates()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Luego de eliminar los duplicados, recorda reiniciar el indice tras la eliminación. Ya que el índice queda desordenado, dificultando manipulaciones. Al reiniciarlo, se obtiene un índice ordenado y se conserva el original en una nueva columna, preservando la integridad y facilitando futuras referencias . Recorda luego utilizar el parametro drop en true ya que de lo contrario te quedara el indice anterior como columna.
# </div>
#
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy bien.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Corregido, muchas gracias por la observación.
# </div>

# %%
# Vuelve a verificar si hay filas duplicadas
print(instacart.query("order_dow == 3 & order_hour_of_day == 2").duplicated().sum() )
instacart.shape
# Out:
# 0
# (478952, 6)

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
print(instacart['order_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
# - Con el método duplicated() encontramos que hay 15 filas duplicadas en el DataFrame 'Instacart'.
# - Con el método nunique() identificamos la cantidad de valores únicos en la columna 'order_id'. Está columna tiene 478952 valores únicos y al comparar este número con el total filas del Dataframe (478967) encontramos que la diferencia es de 15 filas, por lo tanto tenemos 15 valores que no son únicos.
# - Hacemos un filtro en el DataFrame para que nos muestre todos los pédidos realizamos el día miercoles (3) y a las 2 AM. A través del metodo duplicated(keep = False) encontramos las filas duplicadas. Con esto podemos ver que todas estas 15 filas están totalmente dúplicadas.
# - Procedemos a eliminar los duplicados con drop_duplicates().
# - Validamos nuevamente con el filtro mencionado anteriormente y el método duplicated(), y validamos que ya noo hay duplicados. También a través del método Shape(), validamos las filas total del DataFrame 478592.
# - Finalmente, validamos que no hay ordenes duplicadas.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien limpiados estos duplicados.
#
#
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
print(products.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay ID de departamentos duplicados
print('Estos son los ID de departamentos duplicados: ', products['department_id'].duplicated().sum())
print('Estos son los ID de departamentos únicos: ',products['department_id'].nunique())
# Out:
# Estos son los ID de departamentos duplicados:  49673
# Estos son los ID de departamentos únicos:  21

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
products['product_name'] = products['product_name'].str.upper()

print('Esta es la cantidad de nombres de productos duplicados: ', products['product_name'].duplicated().sum())
print('Esta es la cantidad de valores unicos: ', products['product_name'].nunique())
print()
print(products[products['product_name'].duplicated(keep = False)])
# Out:
# Esta es la cantidad de nombres de productos duplicados:  1361
# Esta es la cantidad de valores unicos:  48332
#
#        product_id                                     product_name  aisle_id  \
# 37             38                                              NaN       100
# 41             42                                  BIOTIN 1000 MCG        47
# 71             72                                              NaN       100
# 109           110                                              NaN       100
# 185           186       FRESH SCENT DISHWASHER DETERGENT WITH DAWN        74
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# ...

# %%
# Revisa si hay nombres duplicados de productos no faltantes
#print(products.query("product_name != 'NaN'").duplicated(keep = False))
print(products.query("product_name != 'NaN'").duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - No hay filas totalmente duplicadas.
# - Si hay ID de departamentos duplicados. En total hay 49.673 duplicados y sólo 21 únicos.
# - Existen 1361 nombres de productos duplicados, 48332 únicos.
# - No hay productos duplicados de productos no faltantes.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto entendiendo estos duplicados.
#
#
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(departments.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de productos
print(departments['department_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - A través del método duplicated() y sum() verifico si hay filas totalmente duplicadas.
# - Aplico el mismo método para verificar si hay ID de departamentos duplicados.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(aisles.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
print(aisles['aisle_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - A través del método duplicated() y sum() verifico si hay filas totalmente duplicadas.
# - Aplico el mismo método para verificar si hay ID de aisle duplicados.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(orders.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
print(orders['order_id'].duplicated().sum())
print(orders[orders['order_id'].duplicated(keep=False)])
# Out:
# 4094961
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4523160 rows x 4 columns]

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - Si se presentan ID de ordenes de productos repetidas, pero esto puede darse por un pedido que involucre varios productos por lo tanto todos los productos quedan registrados bajo el mismo número de orden.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buena seccion.
#
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
print(products['product_name'].isna().sum() )
# Out:
# 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Se presentan 1258 valores ausentes en la columna 'product_name'.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
#products_name_missing = products[products['product_name'].isna()]
#print(products_name_missing)
filtered_products_missing = products[products['product_name'].isna() & (products['aisle_id'] == 100)]
print(filtered_products_missing)
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Filtrando en el DataFrame si todos los valores ausentes tienen el pasillo 100, encuentro que si, los 1258 valores ausentes están asignados a este pasillo.

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
filtered_products_missing_department = products[products['product_name'].isna() & (products['department_id'] == 21)]
print(filtered_products_missing_department)
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Realizando el mismmo filtro, encuentro que las 1258 valores ausentes son del departamento 21.

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
filtered_tables = products[(products['aisle_id']==100) & (products['department_id']== 21)]
print(filtered_tables)
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Todos los datos con pasillo ID 100 y departamento ID 21, son los 1258 valores ausentes.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products['product_name'] = products['product_name'].fillna('unknown')
print(products[products['product_name'] == 'unknown'])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38      unknown       100             21
# 71             72      unknown       100             21
# 109           110      unknown       100             21
# 296           297      unknown       100             21
# 416           417      unknown       100             21
# ...           ...          ...       ...            ...
# 49552       49553      unknown       100             21
# 49574       49575      unknown       100             21
# 49640       49641      unknown       100             21
# 49663       49664      unknown       100             21
# 49668       49669      unknown       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - Reemplazamos los 1258 valores ausentes 'NaN' con 'unknown' y realizamos un filtro para verificar el cambio realizado.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Genial, encontraste muy bien patron de estos nulos.
#
#
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
#filtered_orders_missing = orders.isna()
#print(filtered_orders_missing)
rows_with_NaN = instacart[instacart.isna().any(axis=1)]
print(rows_with_NaN)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# ...

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
rows_with_NaN_No_first_order = instacart[(instacart.isna().any(axis=1)) & (instacart['order_number'] == 1)]
print(rows_with_NaN_No_first_order)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 28        133707   182261             1          3                 10
# 96        787445    25685             1          6                 18
# 100       294410   111449             1          0                 19
# 103      2869915   123958             1          4                 16
# 104      2521921    42286             1          3                 18
# ...          ...      ...           ...        ...                ...
# 478895   2589657   205028             1          0                 16
# 478896   2222353   141211             1          2                 13
# 478922   2272807   204154             1          1                 15
# 478926   2499542    68810             1          4                 19
# 478945   1387033    22496             1          5                 14
#
#         days_since_prior_order
# 28                         NaN
# 96                         NaN
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - Los 28817 valores ausentes corresponden a primeros pédidos de clientes.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy bien comprendiendo los nulos de este dataset.
#
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
orders_rows_with_NaN = orders[orders.isna().any(axis=1)]
print(orders_rows_with_NaN)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
min_value = orders['add_to_cart_order'].min()
max_value = orders['add_to_cart_order'].max()

print('El valor mínimo es: ', min_value)
print('El valor máximo es: ', max_value)
# Out:
# El valor mínimo es:  1.0
# El valor máximo es:  64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - El valor mínimo de productos agregados al carrito son 1 y el máximo son 64.

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
ids_with_NaN = orders[orders['add_to_cart_order'].isna()]['order_id']
ids_with_NaN_list = ids_with_NaN.tolist()
print(ids_with_NaN_list)
print()
print('En total de IDs de pedidos con valor ausente en add_to_cart_order son: ',ids_with_NaN.count())
# Out:
# [2449164, 1968313, 2926893, 1717990, 1959075, 844733, 61355, 936852, 264710, 1717990, 1564093, 129627, 264710, 293169, 2849370, 1386261, 3308010, 903110, 2136777, 3347453, 1888628, 165801, 2449164, 2094761, 3347453, 1038146, 2136777, 2997021, 844733, 844733, 2136777, 813364, 165801, 2256933, 171934, 264710, 2449164, 2409109, 3347453, 813364, 2926893, 936852, 1730767, 1169835, 733526, 844733, 293169, 61355, 903110, 1968313, 733526, 2136777, 2926893, 404157, 1386261, 171934, 3125735, 747668, 3308010, 1169835, 1800005, 1961723, 936852, 2849370, 3308010, 61355, 871281, 1717990, 813364, 388234, 61355, 3125735, 1959075, 61355, 3125735, 1648217, 171934, 3125735, 61355, 1477139, 1959075, 1717990, 1717990, 61355, 1717990, 171934, 1038146, 3308010, 3347453, 102236, 936852, 171934, 1730767, 2926893, 1021563, 1832957, 1959075, 2256933, 1968313, 2721963, 293169, 102236, 3125735, 1959075, 264710, 678116, 1220886, 1386261, 171934, 1959075, 61355, 3308010, 61355, 102236, 388234, 171934, 3308010, 196
# ...

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
filtered_products = orders[orders['add_to_cart_order'].isna()]['order_id'].unique()
print(filtered_products)
print()
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
orders_filtered = orders[orders['order_id'].isin(filtered_products)]
orders_filtered = orders_filtered.sort_values(by='order_id', ascending=True)

# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
orders_groupby = orders_filtered.groupby('order_id')['product_id'].count().min()
print('El valor mínimo es: ',orders_groupby)


#id_groupby = orders_rows_with_NaN.groupby('order_id')['product_id'].size()
#print(id_groupby)
#print()
#print('El valor mínimo es: ', id_groupby.min())
#print('El valor máximo es: ', id_groupby.max())
# Out:
# [2449164 1968313 2926893 1717990 1959075  844733   61355  936852  264710
#  1564093  129627  293169 2849370 1386261 3308010  903110 2136777 3347453
#  1888628  165801 2094761 1038146 2997021  813364 2256933  171934 2409109
#  1730767 1169835  733526  404157 3125735  747668 1800005 1961723  871281
#   388234 1648217 1477139  102236 1021563 1832957 2721963  678116 1220886
#  1673227 2999801 1633337 2470674 2625444 1677118 2479011 3383594 1183255
#  1713430 2652650 1598369 1916118  854647 1302315  888470  180546 2621907
#  1308785 2729254    9310 2170451 2979697 1625713 1529171]
#
# El valor mínimo es:  65

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor </b> <a class="tocSkip"></a>
#
# En razon de la pregunta si `¿Todos los pedidos con valores ausentes tienen más de 64 productos?`
#
# Podes buscar las `order_id` que tienen valores ausentes en la columna 'add_to_cart_order'.
#
# Después de identificar los IDs -unicos- de pedidos con valores ausentes, asegúrate de filtrar el DataFrame original para incluir solo las filas correspondientes a esos IDs de pedidos antes de realizar la agrupación (Verifica que se encuentren en el primer filtrado los datos). Esto asegurará que estás trabajando solo con los datos relevantes. (Como consejo utiliza en la agrupacion la id de orden pero utilizando el metodo unique para depurar)
#
# Al calcular la cantidad mínima de productos, asegúrate de que estás obteniendo la cantidad mínima de productos en un solo pedido con valores ausentes, no la cantidad mínima entre todos los pedidos agrupados. Revisa cómo estás aplicando la función de conteo y la función de mínimo para obtener el resultado correcto.
# </div>
#
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, perfecto.
#
# </div>

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# - Ningún pedido con valores ausentes tiene más de 64 productos.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Se corrigé el ejercicio, y se encuentra que son 70 pédidos que tienen valores ausentes en la columna 'add_to_cart_order'. De estos 70 pédidos, el pédido con el menor número de productos es el 9310 con 65 productos. Por lo tanto, es verdadero que todos los pédidos con valores ausentes tienen más de 64 productos.
# Muchas gracias por la observación.
# </div>

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
orders['add_to_cart_order'] = orders['add_to_cart_order'].fillna(999).astype(int)
print(orders[orders['add_to_cart_order'] == 999])
print()
orders.info()
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                999          0
# 9926      1968313       43867                999          0
# 14394     2926893       11688                999          0
# 16418     1717990        4142                999          0
# 30114     1959075       42828                999          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                999          0
# 4511400   1633337         260                999          0
# 4517562    404157        9517                999          0
# 4534112   1673227       17835                999          0
# 4535739   1832957       17949                999          1
#
# [836 rows x 4 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# - Se reemplazaron con el método fillna() todos los valores ausentes por 999 y la columna es ahora de tipo entero.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¿Por que crees que el maximo de `add_to_cart_order` se detiene en 64? ¿No crees que es un valor muy arbitrario?</div>
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, en este caso es muy probable que se haya almacenado como int64 por lo que se limito a solo ese numero -como maximo-, comentarle este tipo de problemas al cliente hara que nuestros datos sean mas completos.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Si, es arbitrario y se debe a que 64 es el valor máximo de la columna, no el valor máximo de productos por pédido, el cual es 127 sobre los productos que no tienen valores ausentes, como se observa en el código que está debajo de este comentario.
# Muchas gracias.
# </div>

# %%
orders_complete = orders[~orders['add_to_cart_order'].isna()]['order_id'].unique()
orders_complete_filtered = orders[orders['order_id'].isin(orders_complete)]
orders_complete_filtered = orders_complete_filtered.sort_values(by='order_id', ascending=True)
orders_complete_filtered_groupby = orders_complete_filtered.groupby('order_id')['product_id'].count().max()
print(orders_complete_filtered_groupby)
# Out:
# 127

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
# - Evaluamos todos los DataFrames para identificar si tenian valores duplicados y/o ausentes.
# - Corregimos estos valores para poder pasar a trabajar con los datos.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Buena conclusion intermedia.
#
#
# </div>

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
#Verificar que se puede trabajar con los valores de la columna 'order_hour_of_day'
print(instacart['order_hour_of_day'].min())
print(instacart['order_hour_of_day'].max())
print()
#rasonable_hours = instacart['order_hour_of_day'].between(0, 23)
#print(rasonable_hours)
print(instacart['order_hour_of_day'].unique())
# Out:
# 0
# 23
#
# [13 12 19 20 11  8 18 15 16  9 22 10  0 14 17  1  7  6  2 21  3 23  5  4]

# %%
#Verificar que se puede trabajar con los valores de la columna 'order_dow'
print(instacart['order_dow'].min())
print(instacart['order_dow'].max())
print()
print(instacart['order_dow'].unique())
# Out:
# 0
# 6
#
# [6 5 0 4 3 1 2]

# %% [markdown]
# Escribe aquí tus conclusiones
# - A través de los métodos min(), max() y unique() podemos verificar que las horas van de 0 a 23 y los días van de 0 a 6. Adicionalmente, todos los valores de las dos colummnas están dentro de estos rangos.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto.
#
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
#import pandas as pd
#from matplotlib import pyplot as plt
#instacart = pd.read_csv('/datasets/instacart_orders.csv', sep = ';')

instacart['order_hour_of_day'].hist()
plt.title('Number of people ordening per hour')
plt.xlabel('Hour of day')
plt.ylabel('Number of people')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor </b> <a class="tocSkip"></a>
#
# Siguiendo las buenas practicas importa matplotlib en la celda del inicio (del  proyecto) -donde importaste pandas- y dedicala exclusivamente a la importacion de librerias.
#
# Esteo es importante por varios puntos
#
# - Tener todas las importaciones en un solo lugar facilita la lectura y comprensión del código, si yo al abrir un proyecto veo las librerias se de que va a ir el trabajo (por ejemplo si importa matplotlib habra graficos)
# - Otro beneficio es la detección temprana de errores ya que importar todas las librerías al inicio permite detectar errores de importación (como bibliotecas faltantes o incompatibilidades) antes de ejecutar cualquier linea de codigo.
#
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Corregido.
# Muchas gracias.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta muy bien la extraccion. Para estos casos lo mejor es crear un grafico de barras ya que las horas (0-23) son categorías discretas, y un gráfico de barras representa claramente cada categoría en el eje X, mostrando la cantidad de pedidos por cada hora específica. El histograma, por otro lado, está diseñado para representar distribuciones de datos continuos.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Corregido al final. No sé porqué pero intenté hacerlo en este espacio y no lo logré.
# Muchas gracias.
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# - Podemos observar que apróximadamente después de las 7 horas, comienzan a aumentar considerablemente la cantidad de personas que realizan ordenes.
# - Alrededor de las 15 horas, se alcanza el máximo de personas (cerca de 120.000 personas) y a partir de ahí, comienza a decrecer hasta después de las 20 horas.

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
instacart['order_dow'].hist()
plt.title('What day people buy groceries')
plt.xlabel('Weekday')
plt.ylabel('Number of people')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta muy bien la extraccion. Para estos casos lo mejor es crear un grafico de barras ya que los dias son categorías discretas, y un gráfico de barras representa claramente cada categoría en el eje X, mostrando la cantidad de pedidos por cada dia  específico. El histograma, por otro lado, está diseñado para representar distribuciones de datos continuos.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Corregido al final. No sé porqué pero intenté hacerlo en este espacio y no lo logré.
# Muchas gracias.
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# - Todos los días de la semana, las personas compran productos, pero son los días Domingo y Lunes, donde más personas compran víveres.

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
instacart['days_since_prior_order'].hist()
plt.title('How many days people wait for next order')
plt.xlabel('Number of days')
plt.ylabel('Number of people')

plt.show()

print('Número mínimo de días antes de hacer otro pédido',instacart['days_since_prior_order'].min() )
print('Número máximo de días antes de hacer otro pédido',instacart['days_since_prior_order'].max() )
# Out:
# Número mínimo de días antes de hacer otro pédido 0.0
# Número máximo de días antes de hacer otro pédido 30.0

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta perfecta la extraccion. Para estos casos lo mejor es crear un grafico de barras ya que los dias (0-30) son categorías discretas, y un gráfico de barras representa claramente cada categoría en el eje X, mostrando la cantidad de pedidos por cada hora específica. El histograma, por otro lado, está diseñado para representar distribuciones de datos continuos.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Corregido al final. No sé porqué pero intenté hacerlo en este espacio y no lo logré.
# Muchas gracias.
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# - Es bastante variado el número de días que las personas esperan para hacer un nuevo pedido.
# - Entre el segundo y noveno día, la mayoría de personas vuelven a realizar un nuevo pedido, sin embargo, un número consirable de personas realiza pedidos al siguiente día de la última compra y a los 30 días.
# - Se podría inferir que aquellos clientes que vuelven a ordenar a los 30 días, son clientes que realizan sus compras para todo el mes. Por otra parte, la mayoria de las personas realiza nuevos pedidos antes del decimo día.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buenas conclusiones
#
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
#import pandas as pd
#from matplotlib import pyplot as plt
#instacart = pd.read_csv('/datasets/instacart_orders.csv', sep = ';')

instacart_wednesday = instacart[instacart['order_dow'] == 3]
instacart_saturday = instacart[instacart['order_dow'] == 6]

order_counts_wednesday = instacart_wednesday['order_hour_of_day'].value_counts().sort_index()
order_counts_saturday = instacart_saturday['order_hour_of_day'].value_counts().sort_index()

plt.figure(figsize=(10, 6))

plt.bar(order_counts_wednesday.index - 0.2, order_counts_wednesday.values, width=0.4, label='Wednesday', color='blue')
plt.bar(order_counts_saturday.index + 0.2, order_counts_saturday.values, width=0.4, label='Saturday', color='orange')

plt.xlabel('Hour of day')
plt.ylabel('Number of orders')
plt.title('Wednesday & Saturday order distribution')
plt.legend()
plt.xticks(range(0, 24))

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# No importes pandas ni matplotlib ya que lo has hecho al principio, no constituye una buena practica hacerla todo el tiempo.
# Otra cosa que no se debe hacer es cargar nuevamente el dataset(con el read). Ya que estaras todo el tiempo cancelando tu progreso con el mismo, en el momento que lo haces reinicias todos los cambios, por esto es que se carga solo al principio.
#
# Cuando hacemos un notebook lo que hacemos al principio se mantiene ejecutado a lo largo de todo el proyecto, por eso realizamos  por etapa el codigo y no todo en una sola celda.
#
# Si no estas observando los cambios esto es debido a que se pudo desconectar el notebook y dejar de leer las librerias y la carga del dataset, siempre que realicemos cambios o no nos funcione el dataset debemos correr todo el codigo (**Cell-> Run All**).
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Corregido.
# Muchas gracias.
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# - Se presentan distribuciones similares entre los dos días, pero los días Sábados se observa que más personas realizan pedidos entre las 11 y 14 horas. Esto puedo estar relacionado con que no todas las personas trabajan los Sábados y pueden destinar estas horas del días a comprar.
# - Es interesante que entre las 6 y 10 horas más personas realizan pedidos los Miércoles.

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
instacart['order_number'].hist(bins=20)
plt.title('Orders per client distribution')
plt.xlabel('Number of orders per client')
plt.ylabel('Number of clients')

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# - Con base en la distribución se observa como la mayor cantidad de clientes se ubica entre 1 y 20 pedidos. Dentro de este rango, la mayor cantidad de clientes está entre 1 y 5 pédidos.
# - Es interesante que la mayoria de las personas, vuelven a realizar un pedido. Esto puede indicar que los clientes valores el servicio que se les ofrece, y por ende, vuelven a realizar pedidos.
# - Se observa un gran cantidad de clientes que son fieles a la aplicación y tienen más 20 pedidos realizados. Sería interesante un plan de fidelización para retener a estos clientes.
# - A su vez conocer que valoran los clientes con más de 20 pedidos, pero así poder identificar las puntos fuertes y hacer que más clientes acumulen mayor cantidad de pedidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente extraccion.
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
#import pandas as pd
#orders = pd.read_csv('/datasets/order_products.csv', sep = ';')
#products = pd.read_csv('/datasets/products.csv', sep = ';')

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# No importes pandas ya que lo has hecho al principio, no constituye una buena practica hacerla todo el tiempo.
# Otra cosa que no se debe hacer es cargar nuevamente el dataset(con el read). Ya que estaras todo el tiempo cancelando tu progreso con el mismo, en el momento que lo haces reinicias todos los cambios, por esto es que se carga solo al principio.
#
# Cuando hacemos un notebook lo que hacemos al principio se mantiene ejecutado a lo largo de todo el proyecto, por eso realizamos  por etapa el codigo y no todo en una sola celda.
#
# Si no estas observando los cambios esto es debido a que se pudo desconectar el notebook y dejar de leer las librerias y la carga del dataset, siempre que realicemos cambios o no nos funcione el dataset debemos correr todo el codigo (**Cell-> Run All**).
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %% [markdown]
# </div><div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Corregido.
# Muchas gracias.
# </div>

# %%
#Agrupar por producto y contar el número de ordenes por producto
products_groupby = orders.groupby(['product_id'])['order_id'].count().reset_index()
#Definir rotulos de columnas 
products_groupby.columns = ['product_id','total_orders']
#Unir DataFrames por ID de producto para traer el nombre del producto
top_20_products_with_name = pd.merge(products_groupby, products, on='product_id', how='left')
#Ordenar productos con más ordenes de mayor a menor y mostrar los primeros 20 productos
top_20_products = top_20_products_with_name.sort_values(by='total_orders', ascending=False).head(20)
#Definir columnas que interesan
top_20_products_final = top_20_products[['product_id','product_name','total_orders']]

# %%
print(top_20_products_final)
# Out:
#        product_id              product_name  total_orders
# 22808       24852                    BANANA         66050
# 12025       13176    BAG OF ORGANIC BANANAS         53297
# 19370       21137      ORGANIC STRAWBERRIES         37039
# 20077       21903      ORGANIC BABY SPINACH         33971
# 43271       47209      ORGANIC HASS AVOCADO         29773
# 43788       47766           ORGANIC AVOCADO         24689
# 43663       47626               LARGE LEMON         21495
# 15364       16797              STRAWBERRIES         20018
# 24047       26209                     LIMES         19690
# 25556       27845        ORGANIC WHOLE MILK         19600
# 25666       27966       ORGANIC RASPBERRIES         19197
# 21025       22935      ORGANIC YELLOW ONION         15898
# 22908       24964            ORGANIC GARLIC         15292
# 41244       45007          ORGANIC ZUCCHINI         14584
# 35996       39275       ORGANIC BLUEBERRIES         13879
# ...

# %%
plt.figure(figsize=(12, 8)) 

# Gráfico
plt.bar(top_20_products_final['product_name'], top_20_products_final['total_orders'])

# Elementos del gráfico
plt.title('Top 20 productos más pedidos')
plt.xlabel('Producto')
plt.ylabel('Número de órdenes')

# Rotar las etiquetas del eje X para mejor legibilidad
plt.xticks(rotation=45, ha='right')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente. Ordenar los valores hara que la extraccion sea aun mas clara.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy buen grafico.</div>

# %% [markdown]
# </div><div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Corregido.
# Muchas gracias.
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# - Podemos observar que el producto más pedido la Banana.
# - También encontramos que en este top 20 predominan frutas y vegetales. Esto se debe a que son productos perecederos que deben comprarse frecuentemente.
# - Que las frutas y vegetales sea lo más vendido en esta plataforma indica que son de buena calidad y son productos frescos, que los clientes valoran.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
#import pandas as pd
#from matplotlib import pyplot as plt

products_by_order = orders.groupby(['order_id'])['product_id'].count()
products_by_order_average = products_by_order.std()
products_by_order_average_round = round(products_by_order_average,2)
print('El promedio de articulos que las personas compran en un pedido es: ',products_by_order_average_round)

#print(orders.sort_values(by='order_id', ascending=True).head(20))
# Out:
# El promedio de articulos que las personas compran en un pedido es:  7.54

# %%
#orders = pd.read_csv('/datasets/order_products.csv', sep = ';')
products_by_order = orders.groupby(['order_id'])['product_id'].count()
products_by_order.plot(kind='hist',
                       bins=range(1, products_by_order.max() + 1),
                       title = 'Products by order distribution', 
                       edgecolor='black',
                       figsize= (10, 6))
                       
plt.xlabel('Products by order')
plt.ylabel('Number of orders')
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# No importes pandas ya que lo has hecho al principio, no constituye una buena practica hacerla todo el tiempo.
# Otra cosa que no se debe hacer es cargar nuevamente el dataset(con el read). Ya que estaras todo el tiempo cancelando tu progreso con el mismo, en el momento que lo haces reinicias todos los cambios, por esto es que se carga solo al principio.
#
# Cuando hacemos un notebook lo que hacemos al principio se mantiene ejecutado a lo largo de todo el proyecto, por eso realizamos  por etapa el codigo y no todo en una sola celda.
#
# Si no estas observando los cambios esto es debido a que se pudo desconectar el notebook y dejar de leer las librerias y la carga del dataset, siempre que realicemos cambios o no nos funcione el dataset debemos correr todo el codigo (**Cell-> Run All**).
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta perfecto el grafico, como consejo podrias graficar  (en otra celda) el top 30 o 40 para visualizar mejor los datos ya que a partir de alli practicamente no tenemos informacion.</div>

# %%
print(products_by_order.describe())
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: product_id, dtype: float64

# %% [markdown]
# Escribe aquí tus conclusiones
# - el promedio de productos por pedido es 7.54.

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
products_reordered = orders[orders['reordered'] == 1]

# %%
most_reordered_products = products_reordered.groupby('product_id')['reordered'].count().reset_index()
most_reordered_products.columns = ['product_id','total_orders']
most_reordered_products_with_name = pd.merge(most_reordered_products, products, on='product_id', how='left')
most_reordered_products_final = most_reordered_products_with_name[['product_id','product_name','total_orders']]

# %%
print(most_reordered_products_final.sort_values(by='total_orders', ascending=False).head(20))
# Out:
#        product_id              product_name  total_orders
# 18104       24852                    BANANA         55763
# 9528        13176    BAG OF ORGANIC BANANAS         44450
# 15368       21137      ORGANIC STRAWBERRIES         28639
# 15936       21903      ORGANIC BABY SPINACH         26233
# 34407       47209      ORGANIC HASS AVOCADO         23629
# 34828       47766           ORGANIC AVOCADO         18743
# 20285       27845        ORGANIC WHOLE MILK         16251
# 34725       47626               LARGE LEMON         15044
# 20375       27966       ORGANIC RASPBERRIES         14748
# 12193       16797              STRAWBERRIES         13945
# 19088       26209                     LIMES         13327
# 16700       22935      ORGANIC YELLOW ONION         11145
# 18186       24964            ORGANIC GARLIC         10411
# 32792       45007          ORGANIC ZUCCHINI         10076
# 36219       49683            CUCUMBER KIRBY          9538
# ...

# %%
top_20_reordered_products = most_reordered_products_final.sort_values(by='total_orders', ascending=False).head(20)

# Gráfico de barras
plt.figure(figsize=(12, 8)) 

plt.bar(top_20_reordered_products['product_name'], top_20_reordered_products['total_orders'])

plt.title('Top 20 most reordered products')
plt.xlabel('Products')
plt.ylabel('Orders')

# Rotar las etiquetas del eje X para mejor legibilidad
plt.xticks(rotation=45, ha='right')


# Mostrar el gráfico
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente. Ordenar los valores hara que la extraccion sea aun mas clara.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %% [markdown]
# </div><div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Muchas gracias.
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones
# - Después de filtrar el DataFrame 'orders' por los productos que se reordenan, y realizar el groupby, se encuentra que la Banana es el producto que más se reordena.

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
def calcular_proporcion_reordenado(df):
    # Contamos el total de pedidos y los pedidos reordenados por cada producto
    total_pedidos = orders.groupby('product_id').size()
    pedidos_reordenados = orders[orders['reordered'] == 1].groupby('product_id').size()

    # Calcular la proporción de reordenados sobre el total
    proporcion_reordenado = pedidos_reordenados / total_pedidos
    
    # Calcular la proporción de no reordenados (1 - proporción de reordenados)
    proporcion_ordenado = 1 - proporcion_reordenado
    
    # Unir los resultados en un solo DataFrame
    result = pd.DataFrame({
        'product_id': total_pedidos.index,
        'proporcion_ordenado': proporcion_ordenado.values,
        'proporción_reordenado': proporcion_reordenado.values        
    }).reset_index(drop=True)
    
    return result

# Calcular las proporciones
proporciones = calcular_proporcion_reordenado(orders)

print(proporciones)
# Out:
#        product_id  proporcion_ordenado  proporción_reordenado
# 0               1             0.435714               0.564286
# 1               2                  NaN                    NaN
# 2               3             0.261905               0.738095
# 3               4             0.489796               0.510204
# 4               7             0.500000               0.500000
# ...           ...                  ...                    ...
# 45568       49690             0.200000               0.800000
# 45569       49691             0.569444               0.430556
# 45570       49692             0.583333               0.416667
# 45571       49693             0.560000               0.440000
# 45572       49694             0.666667               0.333333
#
# [45573 rows x 3 columns]

# %% [markdown]
# Escribe aquí tus conclusiones:
# - Con este resultado podemos identificar los productos que más y menos se reordenan, y buscar optimizaciones de inventario
# - para mejorar el flujo de caja.
# - También para los productos con mayor proporción, podemos identificar en que productos no se debe depender de un solo proveedor.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buena extraccion.
#
# </div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
#Unir los DataFrames que se requieren
new_data_frame = pd.merge(orders, instacart, on='order_id', how='left')
new_data_frame = new_data_frame[['user_id','product_id','reordered']]

# %%
def calculate_common_products(df):
    # Calcular el total de productos únicos ordenados por cada cliente
    total_products_by_client = new_data_frame.groupby('user_id')['product_id'].nunique()
    # Calcular el total de productos reordenados por cada cliente
    reordered_products_by_client = new_data_frame[new_data_frame['reordered'] == 1].groupby('user_id')['product_id'].nunique()
    
    # Calcular la proporción de productos reordenados por cliente
    products_reordered_by_client = reordered_products_by_client / total_products_by_client
    
    # Crear un DataFrame con los resultados
    result = pd.DataFrame({
        'user_id': products_reordered_by_client.index,
        'products_reordered_by_client': products_reordered_by_client.values
    }).reset_index(drop=True)
    
    return result

percentaje = calculate_common_products(new_data_frame)

print(percentaje)
# Out:
#         user_id  products_reordered_by_client
# 0             2                      0.040000
# 1             4                           NaN
# 2             5                      0.666667
# 3             6                           NaN
# 4             7                      0.923077
# ...         ...                           ...
# 149621   206203                      0.222222
# 149622   206206                      0.705882
# 149623   206207                      0.848485
# 149624   206208                      0.612500
# 149625   206209                      0.320000
#
# [149626 rows x 2 columns]

# %% [markdown]
# Escribe aquí tus conclusiones
# - Con este resultado, ahora conocemos que proporción de productos los clientes ya habían pedido anteriormente.
# - De esta forma se puede identificar a los clientes más recurrentes y fieles.
# - Entre más alta la proporción, significa que son clientes que realizan pedidos constantemente.
# - Se pueden segmentar dichos clientes para conocer los productos que solicitan y generar descuentos especificos y
# - campañas para impulsar ventas y continuar fidelizando los clientes.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Perfecto.
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
#Realizamos un groupby por el orden en que colocan los productos en el carrito y la identificación del producto
#Esto nos arroja la cantidad de veces que colocaron el producto X en el carrito en la posición Y.  
Top20_first_products = orders.groupby(['add_to_cart_order','product_id']).size().reset_index()
#Asignamos rotulos a las columnas 
Top20_first_products.columns=('add_to_cart_order','product_id','count')
#Treamos el nombre del producto de otro DataFrame con el ID de producto
Top20_first_products_with_name = pd.merge(Top20_first_products, products, on='product_id', how='left')
#Definimos las columnas que nos interesa mostrar
Top20_first_products_final = Top20_first_products_with_name[['add_to_cart_order','product_name','count']]
#Imprimimos el resultado
print(Top20_first_products_final.sort_values(['add_to_cart_order', 'count'], ascending=[True, False]).head(20))
# Out:
#        add_to_cart_order                 product_name  count
# 13414                  1                       BANANA  15562
# 7127                   1       BAG OF ORGANIC BANANAS  11026
# 15028                  1           ORGANIC WHOLE MILK   4363
# 11384                  1         ORGANIC STRAWBERRIES   3946
# 25439                  1         ORGANIC HASS AVOCADO   3390
# 11786                  1         ORGANIC BABY SPINACH   3336
# 25732                  1              ORGANIC AVOCADO   3044
# 10622                  1                 SPRING WATER   2336
# 9050                   1                 STRAWBERRIES   2308
# 15102                  1          ORGANIC RASPBERRIES   2024
# 24024                  1   SPARKLING WATER GRAPEFRUIT   1914
# 26519                  1          ORGANIC HALF & HALF   1797
# 25658                  1                  LARGE LEMON   1737
# 115                    1                         SODA   1733
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recorda que en este caso le agregaria valor graficar ese top 20 con un grafico de barras. Tener a mano el grafico hara mas amena y legible la experiencia del cliente. Ordenar estos valores hará que  quede aun mas clara la distribucion.</div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido.</div>

# %% [markdown]
# </div><div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Muchas gracias.
# </div>

# %%
first_20_products = Top20_first_products_final.sort_values(['add_to_cart_order', 'count'], ascending=[True, False]).head(20)

# Crear el gráfico de barras vertical
plt.figure(figsize=(12, 8))  # Tamaño del gráfico

# Crear las barras
plt.bar(first_20_products['product_name'], first_20_products['count'])

# Añadir título y etiquetas
plt.title('First 20 ordered products')
plt.xlabel('Products')
plt.ylabel('Add to car frequence')

# Rotar las etiquetas del eje X para mejor legibilidad
plt.xticks(rotation=45, ha='right')


# Mostrar el gráfico
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# - Observamos los 20 producos que primero son agregados a los carritos de los clientes.
# - La Banana es el producto estrella de la plataforma.
# - Frutas, verduras y leches los primeros productos que compran los clientes.
# - Estos productos siempre deben contar con inventario, son los que los clientes buscan primero y/o por el producto que
# - utilizan la plataforma.

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# </div><div class="alert alert-block alert-info">
#
# - Se realiza un proyecto completo con alistamiento y análisis de datos.
# - Se generan conclusiones importantes sobre los productos más vendidos
# - Se identifican productos con alta proporción a ser reordenados y que siempre se debe tener inventario.
# - Se identifica los productos que se deben tener varios proveedores para no afectar al cliente.
# - Se identifican los días y horas en que más pedidos se realizan.
# - Con estos resultados se pueden crear campañas de fidelización de clientes
# - Se puede segmentar a los cientes que más compras realizan y que productos solicitan
# - Se puede identificar los productos estrella y que hacen que los clientes prefieran esta plataforma.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Esta bien planteada esta conclusion, recorda hacerla en formato **markdown**.
#
# </div>
#
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor #2</b> <a class="tocSkip"></a>
#
# Corregido, muy bueno.</div>

# %% [markdown]
# </div><div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Creo que corregí todo, muchas gracias.
# </div>

# %%
#Corrección 7.2
plt.figure(figsize=(10, 6))
instacart['order_hour_of_day'].value_counts().sort_index().plot(kind='bar')

#Elementos del gráfico
plt.title('Number of people ordening per hour')
plt.xlabel('Hour of day')
plt.ylabel('Number of people')

#Imprimir gráfico
plt.show()

# %%
#Correción 7.3
plt.figure(figsize=(10, 6))
instacart['order_dow'].value_counts().sort_index().plot(kind='bar')

plt.title('What day people buy groceries')
plt.xlabel('Weekday')
plt.ylabel('Number of people')

plt.show()

# %%
#Corrección 7.4 
plt.figure(figsize=(10, 6))
instacart['days_since_prior_order'].value_counts().sort_index().plot(kind='bar')

#Elementos del gráfico
plt.title('How many days people wait for next order')
plt.xlabel('Number of days')
plt.ylabel('Number of people')

#Imprimir gráfico
plt.show()
